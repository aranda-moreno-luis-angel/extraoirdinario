# %%
import matplotlib.pyplot as plt

print ("DETERMINA LAS RAICES REALES DE:")
print ("f(x)=-0.5x**2+2.5x+4.5")

def f(x):
  #corregir problema, creo que lo logre!!! #solo raiz z=4
#print("Teniendo en cuenta que Ax^2 + Bx + c")
#a = -0.5
#b = 2.5
#c = 4.5
#disc=((b**2)-(z*a*c))
#raiz=(disc)**(0.5)   (return)
#X1=((-b)+raiz)/(2*a)
#X2=((-b)-raiz)/(2*a) 
#(-0.5*x)**2+(2.5*x)+4.5
  return -(0.5*x)**2+(2.5*x)+4.5
 
  print ("ESTA FUNCION AYUDA A ENCONTRAR LAS RAICES DE X:")
  print ("xr=(xl+xu)/2")
  
def comp_xr(xl,xu):
    return (xl+xu)/2

    print ("ESTA FUNCION AYUDA A CALCULAR EL ERROR PORCENTUAL")
    print ("E=|(xu-xl)/(xu+xl)|=100")

def comp_error(xl,xu):
  return abs((xu-xl)/(xu+xl))*100
     
print ("PARA PODER GRAFICAR LA EVOLUCION DE LA RAIZ Y DEL ERROR, SE GENERARAN DOS LISTAS VACIAS")

xr_list = []
e_list = []

#1RA ITERACION

print("\nITERACION 1")
#cambiar xl=5 y xu=10
xl = 5
xu = 10
e_perm = 1

iteracion = 1
 
xr = comp_xr(xl,xu)

print("x_l", xl)
print("x_r", xr)
print("x_u", xu)
#calcular funciones
f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)
#agreando nuevos valores

xr_list.append(xr)
e_list.append(comp_error(xl,xu))

if f_xl*f_xr > 0:
  print("Se descarta el intervalo de x_l a x_r")
  xl = xr
elif f_xu*f_xr > 0:
  print("Se descarta el intervalo de x_r a x_u")
  xu = xr
else:
  print("Se produjo un error")

print("La aproximacion de la raiz es: ", xr)
print("El error es: ",e_list[iteracion - 1], "%")

print("x_l", xl)
print("x_r", xr)
print("x_u", xu)

#ITERACION 2
xr = comp_xr(xl,xu)
iteracion += 1
print("\nITERACION #2")
print("x_l", xl)
print("x_r", xr)
print("x_u", xu)
#calcular funciones
f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)
#agreando nuevos valores

xr_list.append(xr)
e_list.append(comp_error(xl,xu))

if f_xl*f_xr > 0:
  print("Se descarta el intervalo de x_l a x_r")
  xl = xr
  print("El nuevo valor de xl es: ",xl)
elif f_xu*f_xr > 0:
  print("Se descarta el intervalo de x_r a x_u")
  xu = xr
  print("El nuevo valor de xu es: ",xu)
else:
  print("Se produjo un error")

print("La aproximacion de la raiz es: ", xr)
print("El error es: ",e_list[iteracion - 1], "%")

#ITERACION 3
xr = comp_xr(xl,xu)
iteracion += 1
print("\nITERACION #3")
print("x_l", xl)
print("x_r", xr)
print("x_u", xu)
#calcular funciones
f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)
#agreando nuevos valores

xr_list.append(xr)
e_list.append(comp_error(xl,xu))

if f_xl*f_xr > 0:
  print("Se descarta el intervalo de x_l a x_r")
  xl = xr
  print("El nuevo valor de xl es: ",xl)
elif f_xu*f_xr > 0:
  print("Se descarta el intervalo de x_r a x_u")
  xu = xr
  print("El nuevo valor de xu es: ",xu)
else:
  print("Se produjo un error")

print("La aproximacion de la raiz es: ", xr)
print("El error es: ",e_list[iteracion - 1], "%")

#ITERACION 4
xr = comp_xr(xl,xu)
iteracion += 1
print("\nITERACION #4")
print("x_l", xl)
print("x_r", xr)
print("x_u", xu)
#calcular funciones
f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)
#agreando nuevos valores

xr_list.append(xr)
e_list.append(comp_error(xl,xu))

if f_xl*f_xr > 0:
  print("Se descarta el intervalo de x_l a x_r")
  xl = xr
  print("El nuevo valor de xl es: ",xl)
elif f_xu*f_xr > 0:
  print("Se descarta el intervalo de x_r a x_u")
  xu = xr
  print("El nuevo valor de xu es: ",xu)
else:
  print("Se produjo un error")

print("La aproximacion de la raiz es: ", xr)
print("El error es: ",e_list[iteracion - 1], "%")

#ITERACION 5
xr = comp_xr(xl,xu)
iteracion += 1
print("\nITERACION #5")
print("x_l", xl)
print("x_r", xr)
print("x_u", xu)
#calcular funciones
f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)
#agreando nuevos valores

xr_list.append(xr)
e_list.append(comp_error(xl,xu))

if f_xl*f_xr > 0:
  print("Se descarta el intervalo de x_l a x_r")
  xl = xr
  print("El nuevo valor de xl es: ",xl)
elif f_xu*f_xr > 0:
  print("Se descarta el intervalo de x_r a x_u")
  xu = xr
  print("El nuevo valor de xu es: ",xu)
else:
  print("Se produjo un error")

print("La aproximacion de la raiz es: ", xr)
print("El error es: ",e_list[iteracion - 1], "%\n\n")


#GRAFICAS
print(xr_list)
print(e_list)

plt.plot(xr_list,label="x_r")
plt.plot(e_list,label="error")
plt.legend()
plt.show()

#metodo de la falsa posicion
# Out:
# DETERMINA LAS RAICES REALES DE:
# f(x)=-0.5x**2+2.5x+4.5
# PARA PODER GRAFICAR LA EVOLUCION DE LA RAIZ Y DEL ERROR, SE GENERARAN DOS LISTAS VACIAS
#
# ITERACION 1
# x_l 5
# x_r 7.5
# x_u 10
# Se descarta el intervalo de x_l a x_r
# La aproximacion de la raiz es:  7.5
# El error es:  33.33333333333333 %
# x_l 7.5
# x_r 7.5
# x_u 10
#
# ITERACION #2
# x_l 7.5
# x_r 8.75
# x_u 10
# Se descarta el intervalo de x_l a x_r
# El nuevo valor de xl es:  8.75
# La aproximacion de la raiz es:  8.75
# El error es:  14.285714285714285 %
#
# ITERACION #3
# x_l 8.75
# x_r 9.375
# x_u 10
# Se descarta el intervalo de x_l a x_r
# El nuevo valor de xl es:  9.375
# La aproximacion de la raiz es:  9.375
# El error es:  6.666666666666667 %
#
# ITERACION #4
# x_l 9.375
# x_r 9.6875
# x_u 10
# Se descarta el intervalo de x_l a x_r
# El nuevo valor de xl es:  9.6875
# La aproximacion de la raiz es:  9.6875
# El error es:  3.225806451612903 %
#
# ITERACION #5
# x_l 9.6875
# x_r 9.84375
# x_u 10
# ...

# %%
import matplotlib.pyplot as plt

def f(x):
  #cambiar retun (0.5*x)**2+(2.5*x)+4.5
  return -(0.5*x)**2+(2.5*x)+4.5
def compute_xr(xl,xu):
  return xu-((f(xu)*(xl-xu))/(f(xl)-f(xu)))
  #cambiar xu=10, xr=5
xu = 10
xl = 5
#iteracion 1
xr = compute_xr(xl,xu)

f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)

print("xl: ", xl)
print("xu: ", xu)
print("xr: ", xr)

print("f(xl): ", f_xl)
print("f(xr): ", f_xr)
print("f(xu): ", f_xu)

intervalo_izquierdo = f_xl*f_xr
print("f(xl)f(xr): ", f_xl*f_xr)
intervalo_derecho = f_xr*f_xu
print("f(xr)f(xu): ", f_xr*f_xu)

error = abs((xu-xl)/(xu+xl))*100
if (intervalo_izquierdo > 0):
  print("Dsecarta: ","xl","->","xr_val")
  xl = xr
if (intervalo_derecho > 0):
  print("Descarta: ","xr_val","->","xu")
  xu = xr
print("Error: ",error)
#itereacion 2
print("\nSegunda iteracion")
xr=compute_xr(xl,xu)

f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)

print("xl: ", xl)
print("xu: ", xu)
print("xr: ", xr)

print("f(xl): ", f_xl)
print("f(xr): ", f_xr)
print("f(xu): ", f_xu)

intervalo_izquierdo = f_xl*f_xr
print("f(xl)f(xr): ", f_xl*f_xr)
intervalo_derecho = f_xr*f_xu
print("f(xr)f(xu): ", f_xr*f_xu)

error = abs((xu-xl)/(xu+xl))*100
if (intervalo_izquierdo > 0):
  print("Dsecarta: ","xl","->","xr_val")
  xl = xr
print("El nuevo valor de xl: ",xl)
if (intervalo_derecho > 0):
  print("Descarta: ","xr_val","->","xu")
  xu = xr
print("El nuevo valor de xu: ",xu)
print("Error: ",error)
#itereacion 3
print("\nTercera iteracion")
xr = compute_xr(xl,xu)

f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)

print("xl: ", xl)
print("xu: ", xu)
print("xr: ", xr)

print("f(xl): ", f_xl)
print("f(xr): ", f_xr)
print("f(xu): ", f_xu)

intervalo_izquierdo = f_xl*f_xr
print("f(xl)f(xr): ", f_xl*f_xr)
intervalo_derecho = f_xr*f_xu
print("f(xr)f(xu): ", f_xr*f_xu)

error = abs((xu-xl)/(xu+xl))*100
if (intervalo_izquierdo > 0):
  print("Dsecarta: ","xl","->","xr_val")
  xl = xr
print("El nuevo valor de xl: ",xl)
if (intervalo_derecho > 0):
  print("Descarta: ","xr_val","->","xu")
  xu = xr
print("El nuevo valor de xu: ",xu)
print("Error: ",error)
#itereacion 4
print("\nCuarta iteracion")
xr = compute_xr(xl,xu)

f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)

print("xl: ", xl)
print("xu: ", xu)
print("xr: ", xr)

print("f(xl): ", f_xl)
print("f(xr): ", f_xr)
print("f(xu): ", f_xu)

intervalo_izquierdo = f_xl*f_xr
print("f(xl)f(xr): ", f_xl*f_xr)
intervalo_derecho = f_xr*f_xu
print("f(xr)f(xu): ", f_xr*f_xu)

error = abs((xu-xl)/(xu+xl))*100
if (intervalo_izquierdo > 0):
  print("Dsecarta: ","xl","->","xr_val")
  xl = xr
print("El nuevo valor de xl: ",xl)
if (intervalo_derecho > 0):
  print("Descarta: ","xr_val","->","xu")
  xu = xr
print("El nuevo valor de xu: ",xu)
print("Error: ",error)
#itereacion 5
print("\nQuinta iteracion")
xr = compute_xr(xl,xu)

f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)

print("xl: ", xl)
print("xu: ", xu)
print("xr: ", xr)

print("f(xl): ", f_xl)
print("f(xr): ", f_xr)
print("f(xu): ", f_xu)

intervalo_izquierdo = f_xl*f_xr
print("f(xl)f(xr): ", f_xl*f_xr)
intervalo_derecho = f_xr*f_xu
print("f(xr)f(xu): ", f_xr*f_xu)

error = abs((xu-xl)/(xu+xl))*100
if (intervalo_izquierdo > 0):
  print("Dsecarta: ","xl","->","xr_val")
  xl = xr
print("El nuevo valor de xl: ",xl)
if (intervalo_derecho > 0):
  print("Descarta: ","xr_val","->","xu")
  xu = xr
print("El nuevo valor de xu: ",xu)
print("Error: ",error)
# Out:
# xl:  5
# xu:  10
# xr:  13.6
# f(xl):  10.75
# f(xr):  -7.739999999999995
# f(xu):  4.5
# f(xl)f(xr):  -83.20499999999994
# f(xr)f(xu):  -34.82999999999998
# Error:  33.33333333333333
#
# Segunda iteracion
# xl:  5
# xu:  10
# xr:  13.6
# f(xl):  10.75
# f(xr):  -7.739999999999995
# f(xu):  4.5
# f(xl)f(xr):  -83.20499999999994
# f(xr)f(xu):  -34.82999999999998
# El nuevo valor de xl:  5
# El nuevo valor de xu:  10
# Error:  33.33333333333333
#
# Tercera iteracion
# xl:  5
# xu:  10
# xr:  13.6
# f(xl):  10.75
# f(xr):  -7.739999999999995
# f(xu):  4.5
# f(xl)f(xr):  -83.20499999999994
# f(xr)f(xu):  -34.82999999999998
# El nuevo valor de xl:  5
# El nuevo valor de xu:  10
# Error:  33.33333333333333
#
# Cuarta iteracion
# xl:  5
# xu:  10
# xr:  13.6
# f(xl):  10.75
# f(xr):  -7.739999999999995
# f(xu):  4.5
# f(xl)f(xr):  -83.20499999999994
# f(xr)f(xu):  -34.82999999999998
# El nuevo valor de xl:  5
# El nuevo valor de xu:  10
# Error:  33.33333333333333
#
# Quinta iteracion
# ...

# %%
#ejercicio 2
import matplotlib.pyplot as plt

print ("DETERMINA LAS RAICES REALES DE:")
print ("f(x)=5*x**3-5*x**2+6*x-2")

def f(x):
  return (5*x**3) - (5*x**2) + 6*x - 2
 
  print ("ESTA FUNCION AYUDA A ENCONTRAR LAS RAICES DE X:")
  print ("xr=(xl+xu)/2")
  
def comp_xr(xl,xu):
    return (xl+xu)/2

    print ("ESTA FUNCION AYUDA A CALCULAR EL ERROR PORCENTUAL")
    print ("E=|(xu-xl)/(xu+xl)|=100")

def comp_error(xl,xu):
  return abs((xu-xl)/(xu+xl))*100
     
print ("PARA PODER GRAFICAR LA EVOLUCION DE LA RAIZ Y DEL ERROR, SE GENERARAN DOS LISTAS VACIAS")

xr_list = []
e_list = []

#1RA ITERACION

print("\nITERACION 1")
#cambiar xl=5 y xu=10
xl = 0
xu = 1
e_perm = 1

iteracion = 1
 
xr = comp_xr(xl,xu)

print("x_l", xl)
print("x_r", xr)
print("x_u", xu)
#calcular funciones
f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)
#agreando nuevos valores

xr_list.append(xr)
e_list.append(comp_error(xl,xu))

if f_xl*f_xr > 0:
  print("Se descarta el intervalo de x_l a x_r")
  xl = xr
elif f_xu*f_xr > 0:
  print("Se descarta el intervalo de x_r a x_u")
  xu = xr
else:
  print("Se produjo un error")

print("La aproximacion de la raiz es: ", xr)
print("El error es: ",e_list[iteracion - 1], "%")

print("x_l", xl)
print("x_r", xr)
print("x_u", xu)

#ITERACION 2
xr = comp_xr(xl,xu)
iteracion += 1
print("\nITERACION #2")
print("x_l", xl)
print("x_r", xr)
print("x_u", xu)
#calcular funciones
f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)
#agreando nuevos valores

xr_list.append(xr)
e_list.append(comp_error(xl,xu))

if f_xl*f_xr > 0:
  print("Se descarta el intervalo de x_l a x_r")
  xl = xr
  print("El nuevo valor de xl es: ",xl)
elif f_xu*f_xr > 0:
  print("Se descarta el intervalo de x_r a x_u")
  xu = xr
  print("El nuevo valor de xu es: ",xu)
else:
  print("Se produjo un error")

print("La aproximacion de la raiz es: ", xr)
print("El error es: ",e_list[iteracion - 1], "%")

#ITERACION 3
xr = comp_xr(xl,xu)
iteracion += 1
print("\nITERACION #3")
print("x_l", xl)
print("x_r", xr)
print("x_u", xu)
#calcular funciones
f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)
#agreando nuevos valores

xr_list.append(xr)
e_list.append(comp_error(xl,xu))

if f_xl*f_xr > 0:
  print("Se descarta el intervalo de x_l a x_r")
  xl = xr
  print("El nuevo valor de xl es: ",xl)
elif f_xu*f_xr > 0:
  print("Se descarta el intervalo de x_r a x_u")
  xu = xr
  print("El nuevo valor de xu es: ",xu)
else:
  print("Se produjo un error")

print("La aproximacion de la raiz es: ", xr)
print("El error es: ",e_list[iteracion - 1], "%")

#ITERACION 4
xr = comp_xr(xl,xu)
iteracion += 1
print("\nITERACION #4")
print("x_l", xl)
print("x_r", xr)
print("x_u", xu)
#calcular funciones
f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)
#agreando nuevos valores

xr_list.append(xr)
e_list.append(comp_error(xl,xu))

if f_xl*f_xr > 0:
  print("Se descarta el intervalo de x_l a x_r")
  xl = xr
  print("El nuevo valor de xl es: ",xl)
elif f_xu*f_xr > 0:
  print("Se descarta el intervalo de x_r a x_u")
  xu = xr
  print("El nuevo valor de xu es: ",xu)
else:
  print("Se produjo un error")

print("La aproximacion de la raiz es: ", xr)
print("El error es: ",e_list[iteracion - 1], "%")

#ITERACION 5
xr = comp_xr(xl,xu)
iteracion += 1
print("\nITERACION #5")
print("x_l", xl)
print("x_r", xr)
print("x_u", xu)
#calcular funciones
f_xl = f(xl)
f_xr = f(xr)
f_xu = f(xu)
#agreando nuevos valores

xr_list.append(xr)
e_list.append(comp_error(xl,xu))

if f_xl*f_xr > 0:
  print("Se descarta el intervalo de x_l a x_r")
  xl = xr
  print("El nuevo valor de xl es: ",xl)
elif f_xu*f_xr > 0:
  print("Se descarta el intervalo de x_r a x_u")
  xu = xr
  print("El nuevo valor de xu es: ",xu)
else:
  print("Se produjo un error")

print("La aproximacion de la raiz es: ", xr)
print("El error es: ",e_list[iteracion - 1], "%\n\n")


#GRAFICAS
print(xr_list)
print(e_list)

plt.plot(xr_list,label="x_r")
plt.plot(e_list,label="error")
plt.legend()
plt.show()
# Out:
# DETERMINA LAS RAICES REALES DE:
# f(x)=5*x**3-5*x**2+6*x-2
# PARA PODER GRAFICAR LA EVOLUCION DE LA RAIZ Y DEL ERROR, SE GENERARAN DOS LISTAS VACIAS
#
# ITERACION 1
# x_l 0
# x_r 0.5
# x_u 1
# Se descarta el intervalo de x_r a x_u
# La aproximacion de la raiz es:  0.5
# El error es:  100.0 %
# x_l 0
# x_r 0.5
# x_u 0.5
#
# ITERACION #2
# x_l 0
# x_r 0.25
# x_u 0.5
# Se descarta el intervalo de x_l a x_r
# El nuevo valor de xl es:  0.25
# La aproximacion de la raiz es:  0.25
# El error es:  100.0 %
#
# ITERACION #3
# x_l 0.25
# x_r 0.375
# x_u 0.5
# Se descarta el intervalo de x_l a x_r
# El nuevo valor de xl es:  0.375
# La aproximacion de la raiz es:  0.375
# El error es:  33.33333333333333 %
#
# ITERACION #4
# x_l 0.375
# x_r 0.4375
# x_u 0.5
# Se descarta el intervalo de x_r a x_u
# El nuevo valor de xu es:  0.4375
# La aproximacion de la raiz es:  0.4375
# El error es:  14.285714285714285 %
#
# ITERACION #5
# x_l 0.375
# x_r 0.40625
# x_u 0.4375
# ...
